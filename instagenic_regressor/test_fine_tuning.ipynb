# %%
import os
import h5py
from keras import backend as K

# %%
import numpy as np
import argparse
from path import Path

from keras.models import Model
from keras.layers import Dense, Dropout
from keras.applications.mobilenet import MobileNet
from keras.applications.mobilenet import preprocess_input
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras.optimizers import Adam
from keras.preprocessing.image import load_img, img_to_array
import tensorflow as tf
from data_loader import train_generator, val_generator
# Out:
# Train set size :  (450,) (450, 5)
# Val set size :  (50,) (50, 5)
# Train and validation datasets ready !

# %%
class TensorBoardBatch(TensorBoard):
    def __init__(self, *args, **kwargs):
        super(TensorBoardBatch, self).__init__(*args)

        # conditionally import tensorflow iff TensorBoardBatch is created
        self.tf = __import__('tensorflow')

    def on_batch_end(self, batch, logs=None):
        logs = logs or {}

        for name, value in logs.items():
            if name in ['batch', 'size']:
                continue
            summary = self.tf.Summary()
            summary_value = summary.value.add()
            summary_value.simple_value = value.item()
            summary_value.tag = name
            self.writer.add_summary(summary, batch)

        self.writer.flush()

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}

        for name, value in logs.items():
            if name in ['batch', 'size']:
                continue
            summary = self.tf.Summary()
            summary_value = summary.value.add()
            summary_value.simple_value = value.item()
            summary_value.tag = name
            self.writer.add_summary(summary, epoch * self.batch_size)

        self.writer.flush()

# %%
def earth_mover_loss(y_true, y_pred):
    cdf_ytrue = K.cumsum(y_true, axis=-1)
    cdf_ypred = K.cumsum(y_pred, axis=-1)
    samplewise_emd = K.sqrt(K.mean(K.square(K.abs(cdf_ytrue - cdf_ypred)), axis=-1))
    return K.mean(samplewise_emd)

# %%
# load learned mobilenet 
weights_path = './neural-image-assessment/weights/mobilenet_weights.h5'

base_model = MobileNet((None, None, 3), alpha=1, include_top=False, pooling='avg', weights=None)
x = Dropout(0.75)(base_model.output)
x = Dense(5, activation='softmax', kernel_initializer='uniform')(x)
model = Model(base_model.input, x)
model.load_weights(weights_path, by_name=True)

# freeze ~88
for layer in model.layers[:79]:
    layer.trainable = False

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, None, None, 3)     0
# _________________________________________________________________
# conv1 (Conv2D)               (None, None, None, 32)    864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, None, None, 32)    128
# _________________________________________________________________
# conv1_relu (Activation)      (None, None, None, 32)    0
# _________________________________________________________________
# conv_pad_1 (ZeroPadding2D)   (None, None, None, 32)    0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, None, None, 32)    288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, None, None, 32)    128
# _________________________________________________________________
# conv_dw_1_relu (Activation)  (None, None, None, 32)    0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, None, None, 64)    2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, None, None, 64)    256
# _________________________________________________________________
# conv_pw_1_relu (Activation)  (None, None, None, 64)    0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, None, None, 64)    0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, None, None, 64)    576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, None, None, 64)    256
# _________________________________________________________________
# conv_dw_2_relu (Activation)  (None, None, None, 64)    0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, None, None, 128)   8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, None, None, 128)   512
# _________________________________________________________________
# conv_pw_2_relu (Activation)  (None, None, None, 128)   0
# _________________________________________________________________
# conv_pad_3 (ZeroPadding2D)   (None, None, None, 128)   0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, None, None, 128)   1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, None, None, 128)   512
# _________________________________________________________________
# conv_dw_3_relu (Activation)  (None, None, None, 128)   0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, None, None, 128)   16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, None, None, 128)   512
# _________________________________________________________________
# conv_pw_3_relu (Activation)  (None, None, None, 128)   0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, None, None, 128)   0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, None, None, 128)   1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, None, None, 128)   512
# _________________________________________________________________
# conv_dw_4_relu (Activation)  (None, None, None, 128)   0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, None, None, 256)   32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, None, None, 256)   1024
# _________________________________________________________________
# conv_pw_4_relu (Activation)  (None, None, None, 256)   0
# _________________________________________________________________
# conv_pad_5 (ZeroPadding2D)   (None, None, None, 256)   0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, None, None, 256)   2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, None, None, 256)   1024
# _________________________________________________________________
# conv_dw_5_relu (Activation)  (None, None, None, 256)   0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, None, None, 256)   65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, None, None, 256)   1024
# _________________________________________________________________
# conv_pw_5_relu (Activation)  (None, None, None, 256)   0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, None, None, 256)   0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, None, None, 256)   2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, None, None, 256)   1024
# _________________________________________________________________
# conv_dw_6_relu (Activation)  (None, None, None, 256)   0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, None, None, 512)   131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_6_relu (Activation)  (None, None, None, 512)   0
# _________________________________________________________________
# conv_pad_7 (ZeroPadding2D)   (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_7_relu (Activation)  (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, None, None, 512)   262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_7_relu (Activation)  (None, None, None, 512)   0
# _________________________________________________________________
# conv_pad_8 (ZeroPadding2D)   (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_8_relu (Activation)  (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, None, None, 512)   262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_8_relu (Activation)  (None, None, None, 512)   0
# _________________________________________________________________
# conv_pad_9 (ZeroPadding2D)   (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_9_relu (Activation)  (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, None, None, 512)   262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_9_relu (Activation)  (None, None, None, 512)   0
# _________________________________________________________________
# conv_pad_10 (ZeroPadding2D)  (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_10_relu (Activation) (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, None, None, 512)   262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_10_relu (Activation) (None, None, None, 512)   0
# _________________________________________________________________
# conv_pad_11 (ZeroPadding2D)  (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_11_relu (Activation) (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, None, None, 512)   262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_11_relu (Activation) (None, None, None, 512)   0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_12_relu (Activation) (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, None, None, 1024)  524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, None, None, 1024)  4096
# _________________________________________________________________
# conv_pw_12_relu (Activation) (None, None, None, 1024)  0
# _________________________________________________________________
# conv_pad_13 (ZeroPadding2D)  (None, None, None, 1024)  0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, None, None, 1024)  9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, None, None, 1024)  4096
# _________________________________________________________________
# conv_dw_13_relu (Activation) (None, None, None, 1024)  0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, None, None, 1024)  1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, None, None, 1024)  4096
# _________________________________________________________________
# conv_pw_13_relu (Activation) (None, None, None, 1024)  0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 3,233,989
# Trainable params: 3,212,101
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
optimizer = Adam(lr=1e-3)
model.compile(optimizer, loss=earth_mover_loss)

checkpoint = ModelCheckpoint('./neural-image-assessment/weights/mobilenet_weights.h5', monitor='val_loss', verbose=1, save_weights_only=True, save_best_only=True,
                             mode='min')
tensorboard = TensorBoardBatch()
callbacks = [checkpoint, tensorboard]

batchsize = 500
epochs = 50

model.fit_generator(train_generator(batchsize=batchsize),
                    steps_per_epoch=1,
                    epochs=epochs, verbose=1, callbacks=callbacks,
                    validation_data=val_generator(batchsize=batchsize),
                    validation_steps=1)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 9s 9s/step - loss: 0.2431 - val_loss: 0.3345
#
# Epoch 00001: val_loss improved from inf to 0.33449, saving model to ./neural-image-assessment/weights/mobilenet_weights.h5
# Epoch 2/50
# 1/1 [==============================] - 1s 906ms/step - loss: 0.2489 - val_loss: 0.3057
#
# Epoch 00002: val_loss improved from 0.33449 to 0.30570, saving model to ./neural-image-assessment/weights/mobilenet_weights.h5
# Epoch 3/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2514 - val_loss: 0.3147
#
# Epoch 00003: val_loss did not improve from 0.30570
# Epoch 4/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2517 - val_loss: 0.3166
#
# Epoch 00004: val_loss did not improve from 0.30570
# Epoch 5/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2461 - val_loss: 0.3090
#
# Epoch 00005: val_loss did not improve from 0.30570
# Epoch 6/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2507 - val_loss: 0.2908
#
# Epoch 00006: val_loss improved from 0.30570 to 0.29085, saving model to ./neural-image-assessment/weights/mobilenet_weights.h5
# Epoch 7/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2582 - val_loss: 0.3548
#
# Epoch 00007: val_loss did not improve from 0.29085
# Epoch 8/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2538 - val_loss: 0.3752
#
# Epoch 00008: val_loss did not improve from 0.29085
# Epoch 9/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2527 - val_loss: 0.2888
#
# Epoch 00009: val_loss improved from 0.29085 to 0.28883, saving model to ./neural-image-assessment/weights/mobilenet_weights.h5
# Epoch 10/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2611 - val_loss: 0.3451
#
# Epoch 00010: val_loss did not improve from 0.28883
# Epoch 11/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2569 - val_loss: 0.3399
#
# Epoch 00011: val_loss did not improve from 0.28883
# Epoch 12/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2525 - val_loss: 0.3461
#
# Epoch 00012: val_loss did not improve from 0.28883
# Epoch 13/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2577 - val_loss: 0.3613
#
# Epoch 00013: val_loss did not improve from 0.28883
# Epoch 14/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2539 - val_loss: 0.3653
#
# Epoch 00014: val_loss did not improve from 0.28883
# Epoch 15/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2540 - val_loss: 0.3320
#
# Epoch 00015: val_loss did not improve from 0.28883
# Epoch 16/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2404 - val_loss: 0.3147
#
# Epoch 00016: val_loss did not improve from 0.28883
# Epoch 17/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2501 - val_loss: 0.3067
#
# Epoch 00017: val_loss did not improve from 0.28883
# Epoch 18/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2537 - val_loss: 0.3546
#
# Epoch 00018: val_loss did not improve from 0.28883
# Epoch 19/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2515 - val_loss: 0.2778
#
# Epoch 00019: val_loss improved from 0.28883 to 0.27780, saving model to ./neural-image-assessment/weights/mobilenet_weights.h5
# Epoch 20/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2394 - val_loss: 0.2952
#
# Epoch 00020: val_loss did not improve from 0.27780
# Epoch 21/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2522 - val_loss: 0.3305
#
# Epoch 00021: val_loss did not improve from 0.27780
# Epoch 22/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2467 - val_loss: 0.3375
#
# Epoch 00022: val_loss did not improve from 0.27780
# Epoch 23/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2595 - val_loss: 0.3741
#
# Epoch 00023: val_loss did not improve from 0.27780
# Epoch 24/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2640 - val_loss: 0.3456
#
# Epoch 00024: val_loss did not improve from 0.27780
# Epoch 25/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2422 - val_loss: 0.3604
#
# Epoch 00025: val_loss did not improve from 0.27780
# Epoch 26/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2444 - val_loss: 0.3677
#
# Epoch 00026: val_loss did not improve from 0.27780
# Epoch 27/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2400 - val_loss: 0.3666
#
# Epoch 00027: val_loss did not improve from 0.27780
# Epoch 28/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2467 - val_loss: 0.4020
#
# Epoch 00028: val_loss did not improve from 0.27780
# Epoch 29/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2345 - val_loss: 0.4101
#
# Epoch 00029: val_loss did not improve from 0.27780
# Epoch 30/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2490 - val_loss: 0.3989
#
# Epoch 00030: val_loss did not improve from 0.27780
# Epoch 31/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2432 - val_loss: 0.4223
#
# Epoch 00031: val_loss did not improve from 0.27780
# Epoch 32/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2460 - val_loss: 0.4042
#
# Epoch 00032: val_loss did not improve from 0.27780
# Epoch 33/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2578 - val_loss: 0.3821
#
# Epoch 00033: val_loss did not improve from 0.27780
# Epoch 34/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2563 - val_loss: 0.3703
#
# Epoch 00034: val_loss did not improve from 0.27780
# Epoch 35/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2497 - val_loss: 0.3615
#
# Epoch 00035: val_loss did not improve from 0.27780
# Epoch 36/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2487 - val_loss: 0.3429
#
# Epoch 00036: val_loss did not improve from 0.27780
# Epoch 37/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2347 - val_loss: 0.2814
#
# Epoch 00037: val_loss did not improve from 0.27780
# Epoch 38/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2454 - val_loss: 0.3092
#
# Epoch 00038: val_loss did not improve from 0.27780
# Epoch 39/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2451 - val_loss: 0.3053
#
# Epoch 00039: val_loss did not improve from 0.27780
# Epoch 40/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2326 - val_loss: 0.3248
#
# Epoch 00040: val_loss did not improve from 0.27780
# Epoch 41/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2293 - val_loss: 0.3434
#
# Epoch 00041: val_loss did not improve from 0.27780
# Epoch 42/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2456 - val_loss: 0.3699
#
# Epoch 00042: val_loss did not improve from 0.27780
# Epoch 43/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2322 - val_loss: 0.3818
#
# Epoch 00043: val_loss did not improve from 0.27780
# Epoch 44/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2411 - val_loss: 0.4073
#
# Epoch 00044: val_loss did not improve from 0.27780
# Epoch 45/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2401 - val_loss: 0.4036
#
# Epoch 00045: val_loss did not improve from 0.27780
# Epoch 46/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2412 - val_loss: 0.4146
#
# Epoch 00046: val_loss did not improve from 0.27780
# Epoch 47/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2375 - val_loss: 0.4021
#
# Epoch 00047: val_loss did not improve from 0.27780
# Epoch 48/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2340 - val_loss: 0.4137
#
# Epoch 00048: val_loss did not improve from 0.27780
# Epoch 49/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2404 - val_loss: 0.4158
#
# Epoch 00049: val_loss did not improve from 0.27780
# Epoch 50/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2377 - val_loss: 0.3946
#
# Epoch 00050: val_loss did not improve from 0.27780
# Exception ignored in: <generator object val_generator at 0x7f1e9f21e4c0>
# Traceback (most recent call last):
#   File "/home/wakacho/jphacks/instagenic_regressor/instagenic_regressor/data_loader.py", line 110, in val_generator
#     yield (X_batch, y_batch)
#   File "/home/wakacho/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1596, in __exit__
#     self._default_graph_context_manager.__exit__(exec_type, exec_value, exec_tb)
#   File "/home/wakacho/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/contextlib.py", line 99, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/home/wakacho/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 5267, in get_controller
#     context.context().context_switches.pop()
#   File "/home/wakacho/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/tensorflow/python/eager/context.py", line 136, in pop
#     self.stack.pop()
# IndexError: pop from empty list
# Exception ignored in: <generator object train_generator at 0x7f1e9ed39db0>
# Traceback (most recent call last):
#   File "/home/wakacho/jphacks/instagenic_regressor/instagenic_regressor/data_loader.py", line 81, in train_generator
#     yield (X_batch, y_batch)
#   File "/home/wakacho/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1596, in __exit__
#     self._default_graph_context_manager.__exit__(exec_type, exec_value, exec_tb)
#   File "/home/wakacho/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/contextlib.py", line 99, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/home/wakacho/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 5267, in get_controller
#     context.context().context_switches.pop()
#   File "/home/wakacho/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/tensorflow/python/eager/context.py", line 136, in pop
#     self.stack.pop()
# IndexError: pop from empty list

# %%
def predict(img_path):
    img = load_img(img_path, target_size=(224, 224))
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)

    scores = model.predict(x, batch_size=1, verbose=0)[0]
    
    return scores

# %%
for filename in ['BJzcrQFjfsQ.jpg',
 'BlSfwPHB5a_.jpg',
 'BlsoWzlFesk.jpg',
 'BmNTJPdHFLI.jpg',
 'Bn-l8xXA1oe.jpg',
 'Bn-mgscAGfH.jpg',
 'Bo1lDTCBL9j.jpg',
 'BoMUTAphCAL.jpg',
 'BoqI5d9h1pi.jpg',
 'BpEQqVMgzRJ.jpg',
 'BpEyhasA9sF.jpg',
 'BpFFLS-hIPb.jpg',
 'BpGUO3IF7af.jpg',
 'BpJv95dnC3n.jpg',
 'BpO-0nKBR3g.jpg',
 'BpO-2YOHIml.jpg',
 'BpO-36fh5z1.jpg',
 'BpO-68Qn_LO.jpg',
 'BpO-AYqFD-9.jpg',
 'BpO-KZQgOq9.jpg']:
    print(filename)
    print(np.argmax(predict('../images/omelette_rice_500/images/'+filename)))
# Out:
# BJzcrQFjfsQ.jpg
# 1
# BlSfwPHB5a_.jpg
# 1
# BlsoWzlFesk.jpg
# 1
# BmNTJPdHFLI.jpg
# 1
# Bn-l8xXA1oe.jpg
# 1
# Bn-mgscAGfH.jpg
# 1
# Bo1lDTCBL9j.jpg
# 1
# BoMUTAphCAL.jpg
# 1
# BoqI5d9h1pi.jpg
# 1
# BpEQqVMgzRJ.jpg
# 1
# BpEyhasA9sF.jpg
# 1
# BpFFLS-hIPb.jpg
# 1
# BpGUO3IF7af.jpg
# 1
# BpJv95dnC3n.jpg
# 1
# BpO-0nKBR3g.jpg
# 1
# BpO-2YOHIml.jpg
# 1
# BpO-36fh5z1.jpg
# 1
# BpO-68Qn_LO.jpg
# 2
# BpO-AYqFD-9.jpg
# 1
# BpO-KZQgOq9.jpg
# 1
